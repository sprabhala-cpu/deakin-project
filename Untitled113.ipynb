# %% [markdown]
# <a href="https://colab.research.google.com/github/sprabhala-cpu/new-webscrapping/blob/main/Untitled113.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
pip install requests-html
# Out:
# ...
#      |████████████████████████████████| 92kB 4.1MB/s
# ...
#      |████████████████████████████████| 81kB 7.5MB/s
# ...
#      |████████████████████████████████| 81kB 7.6MB/s
# ...
#   Created wheel for parse: filename=parse-1.19.0-cp37-none-any.whl size=24581 sha256=893b23f2d88ef439c6228a433f1f9fa10656b83e14b9bbcd013d87393e961fc0
#   Stored in directory: /root/.cache/pip/wheels/c0/39/ea/e2fd678bd130953f5438470b8dfa529f00787e9b8b92b27467
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp37-none-any.whl size=13485 sha256=7b0964aab5a0962a7a4183900a012f895c6578e9798143257eccd11473fe33e0
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built parse fake-useragent
# ERROR: pyppeteer 0.2.5 has requirement urllib3<2.0.0,>=1.25.8, but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...

# %%
import requests

# %%
def url_to_txt(url, file_name="/content/sample_data/world.txt"):
    r = requests.get(url)
    if r.status_code == 200:
        html_text = r.text
        with open(file_name, 'w') as f:
            f.write(r.text)
        return html_text
    return ""
url = "https://www.boxofficemojo.com/year/world"
html_text = url_to_txt(url)

# %%
def convert_to_list_of_list(data_object):
    # get the html data
    html_data = HTML(html=data_object)

# %%
parsed_table = parsed_table = r_table[0]
rows = parsed_table.find("tr")
# the header
header_row = rows[0]
header_row_col = header_row.find("th")
# get the header names
header_name = [x.text for x in header_row_col]
# don't iterate through header elements
for row in rows[1:]:
    cols = row.find("td")

row_data = []
    # get index
for i, col in enumerate(cols):
        # print(i, col.text, "\n\n")
        row_data.append(col.text)
table_data.append(row_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1999a1c9ab1c> in <module>()
# ----> 1 parsed_table = parsed_table = r_table[0]
#       2 rows = parsed_table.find("tr")
#       3 # the header
#       4 header_row = rows[0]
#       5 header_row_col = header_row.find("th")
#
# NameError: name 'r_table' is not defined

# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
def Kompas():
  alamat='https://www.kompas.com/'
  html=urlopen(alamat)
  data=BeautifulSoup(html,'html.parser')
  title=[]
  items=data.findAll('h4',{"class":"most__title"})
  for item in items:
    title.append(item.get_text())
    df = pd.DataFrame(title, columns = ['Judul Berita Populer'])
    print(df)
kompas()
# Out:
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
# 3  Penangkapan Mantan Petinggi FPI Munarman, Didu...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
data_ext=pd.DataFrame(kompas())
# Out:
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
# 3  Penangkapan Mantan Petinggi FPI Munarman, Didu...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
def kompas():
    alamat = "https://www.kompas.com/"
    html = urlopen(alamat)
    data = BeautifulSoup(html, 'html.parser')
    title = []
    items = data.findAll("h4", {"class":"most__title"})
    for item in items:
        title.append(item.get_text())
        df = pd.DataFrame(title, columns = ['Judul Berita Populer'])
        print(df)
kompas()
# Out:
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
# 3  Penangkapan Mantan Petinggi FPI Munarman, Didu...
#                                 Judul Berita Populer
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
# ...

# %%
data_ext
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from urllib.request import urlopen
import pandas as pd
from bs4 import BeautifulSoup

# %%
url='https://www.kompas.com/'
html=urlopen(url)
data=BeautifulSoup(html,'lxml')

# %%
data
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PT7PC4');</script>
# <!-- End Google Tag Manager -->
# <title>Berita Terkini Hari Ini, Kabar Akurat Terpercaya - Kompas.com</title>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//asset.kompas.com" rel="dns-prefetch"/>
# <link href="//adsimg.kompas.com" rel="dns-prefetch"/>
# <link href="//static.criteo.net" rel="dns-prefetch"/>
# <link href="//bidder.criteo.com" rel="dns-prefetch"/>
# <link href="//rtax.criteo.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# ...

# %%
title=[]
items=data.findAll("h4",{'class':'most__title'})
for item in items:
  title.append(item.get_text())

# %%
title
# Out:
# ['Reaksi Menggemaskan Putra Bungsu Sule Sambut Kedatangan Nathalie Holscher',
#  'Detik-detik Penangkapan Munarman, Berdebat dengan Polisi hingga Meminta Pakai Sandal',
#  'Covid-19 di India Melonjak Parah, WHO Sebut Ini Penyebabnya...',
#  'Penangkapan Mantan Petinggi FPI Munarman, Diduga Terkait Baiat ISIS, dan Temuan Bahan Peledak',
#  'Siapa Mafia di Bandara Soekarno-Hatta yang Dibayar Rp 6,5 Juta, Bukan Petugas tapi Punya Kartu Akses?',
#  'Perjalanan Munarman Sebelum Ditangkap, Rekening Diblokir hingga Tuduhan Baiat ISIS',
#  'UAS Ajak Patungan Beli Kapal Selam, Berapa Harga Per Unitnya?',
#  'Bansos Kemensos 2021 Cair Awal Mei, Cek di cekbansos.kemensos.go.id',
#  'Akhir Kasus Mahasiswi Pengemudi Porsche yang Terobos Jalur Busway: Ditilang Rp 500.000 dan Mobil Disita',
#  'Tsunami Covid-19 di India Bisa Jadi Ancaman Global, Ini Sebabnya']

# %%
df=pd.DataFrame(title,columns=['Popular'])

# %%
df
# Out:
#                                              Popular
# 0  Reaksi Menggemaskan Putra Bungsu Sule Sambut K...
# 1  Detik-detik Penangkapan Munarman, Berdebat den...
# 2  Covid-19 di India Melonjak Parah, WHO Sebut In...
# 3  Penangkapan Mantan Petinggi FPI Munarman, Didu...
# 4  Siapa Mafia di Bandara Soekarno-Hatta yang Dib...
# 5  Perjalanan Munarman Sebelum Ditangkap, Rekenin...
# 6  UAS Ajak Patungan Beli Kapal Selam, Berapa Har...
# 7  Bansos Kemensos 2021 Cair Awal Mei, Cek di cek...
# 8  Akhir Kasus Mahasiswi Pengemudi Porsche yang T...
# 9  Tsunami Covid-19 di India Bisa Jadi Ancaman Gl...

# %%
#ndtv news live extraction

# %%
import pandas as pd
import bs4 as BeautifulSoup
from urllib.request import urlopen

# %%
url='https://www.ndtv.com/top-stories?pfrom=home-ndtv_topstories'
html=urlopen(url)
data=BeautifulSoup(html,'lxml')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-69-6bb2957a39c0> in <module>()
#       1 url='https://www.ndtv.com/top-stories?pfrom=home-ndtv_topstories'
# ----> 2 html=urlopen(url)
#       3 data=BeautifulSoup(html,'lxml')
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ...

# %%
from urllib.request import Request, urlopen
from bs4 import  BeautifulSoup

req = Request('https://www.ndtv.com/top-stories?pfrom=home-ndtv_topstories', headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# %%
data=BeautifulSoup(webpage,'lxml')

# %%
data

# %%
title=[]
items=data.findAll('h2',{'class':"newsHdng"})
for item in items:
  title.append(item.get_text())

# %%
title
# Out:
# ['Pfizer Chief Says Oral Drug For COVID-19 Could Be Ready Next Year: Report',
#  "Vaccine Hoarding May Backfire On Nations As India's Surge Threatens World",
#  'Commotion At Jaipur Hospital As Families Protest Deaths Of 4 Covid Patients',
#  '"Made Rich Contributions To Literature": PM Modi Condoles Manoj Das Death',
#  'Joe Biden Gets Outpour Of Bipartisan Support Over Covid Help To India',
#  'Regrets Audio Leak Caused "Domestic Infighting": Iran\'s Foreign Minister',
#  '4 Covid Patients Flee Assam Hospital After Testing Coronavirus Positive',
#  'Vaccine Registration For Those Above 18 Begins At 4 PM. How You Can Do It',
#  'India Daily Covid Deaths Cross 3,000; Record 3.6 Lakh Cases In 24 Hours: 10 Points',
#  '"Government Of Delhi" = "Lieutenant Governor": Controversial Law Kicks In',
#  '"It\'s Like A War": Inside A Delhi Hospital Desperate For Oxygen',
#  'Man Tries To Smuggle 35 Birds Past US Customs For Singing Contests',
# ...

# %%
df=pd.DataFrame(title,columns=['Headers'])

# %%
df['Headers']
# Out:
# 0     Pfizer Chief Says Oral Drug For COVID-19 Could...
# 1     Vaccine Hoarding May Backfire On Nations As In...
# 2     Commotion At Jaipur Hospital As Families Prote...
# 3     "Made Rich Contributions To Literature": PM Mo...
# 4     Joe Biden Gets Outpour Of Bipartisan Support O...
# 5     Regrets Audio Leak Caused "Domestic Infighting...
# 6     4 Covid Patients Flee Assam Hospital After Tes...
# 7     Vaccine Registration For Those Above 18 Begins...
# 8     India Daily Covid Deaths Cross 3,000; Record 3...
# 9     "Government Of Delhi" = "Lieutenant Governor":...
# 10    "It's Like A War": Inside A Delhi Hospital Des...
# 11    Man Tries To Smuggle 35 Birds Past US Customs ...
# 12    Samsung Heirs To Pay Over $10 Billion, Donate ...
# 13    Pics: Damaged Buildings, Cracked Walls As Assa...
# 14    New Vaccine Policy Puts Private Bengal Hospita...
# Name: Headers, dtype: object

# %%
df.to_csv('/content/sample_data/news.csv')

# %%
df
# Out:
#               Headers
# 0          Big Story
# 1       Top Stories
# 2           Opinion
# 3           Top Picks
# 4            Trending
# 5               Tech
# 6              Movies
# 7          Hindi News
# 8        Cricket News
# 9       Business News
# 10         Auto News
# 11       Education
# 12              Food
# 13       LIFESTYLE
# 14        India News
# 15           Offbeat
# 16       Sports News
# 17            Health
# 18      Art & Design
# 19         Campaigns
# 20             Video
# 21             Photos
# 22   NDTV Group Sites

# %%
#important libraries for webscrapping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup

# %%
url='https://www.coursera.org/courses?query=free&page=1'
webpage=urlopen(url)

# %%
data=BeautifulSoup(url,'lxml')
# Out:
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.coursera.org/courses?query=free&page=1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
data
# Out:
# <html><body><p>https://www.coursera.org/courses?query=free&amp;page=1</p></body></html>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import re

# %%
link='https://www.coursera.org/courses?query=free&page=1'

# %%
req = Request('https://www.coursera.org/courses?query=free&page=1', headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# %%
data=BeautifulSoup(webpage,'html.parser')

# %%
data

# %%
title=[]
items=data.findAll('li',{'class':'color-primary-text card-title headline-1-text'})
for item in items:
  title.append(item)

# %%
title
# Out:
# []

# %%
link='https://www.coursera.org/collections/popular-free-courses'
get_website=requests.get(link,timeout=1000)
content=BeautifulSoup(get_website.content)
print(content.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" itemtype="http://schema.org" lang="en" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <link crossorigin="" href="https://d3njjcbhbojbot.cloudfront.net" rel="preconnect"/>
#   <meta content="IE=Edge,chrome=IE7" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="Coursera" property="og:site_name"/>
#   <meta content="727836538,4807654" property="fb:admins"/>
#   <meta content="823425307723964" property="fb:app_id"/>
#   <meta content="Coursera" name="twitter:site"/>
#   <meta content="Coursera" name="twitter:app:name:iphone"/>
#   <meta content="Coursera" name="twitter:app:name:ipad"/>
#   <meta content="Coursera" name="twitter:app:name:googleplay"/>
#   <meta content="id736535961" name="twitter:app:id:iphone"/>
#   <meta content="id736535961" name="twitter:app:id:ipad"/>
#   <meta content="org.coursera.android" name="twitter:app:id:googleplay"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
course_names = []
for i in content.find_all('div', class_='horizontal-box'):
    course = i.find_all('h4', class_='headline-3-text item-name font-weight-bold')
    course_names.append(course)

# %%
course_names
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">The Science of Well-Being</h4>],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">Learning How to Learn: Powerful mental tools to help you master tough subjects</h4>],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">Financial Markets</h4>],
#  [],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">Machine Learning</h4>],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">COVID-19 Contact Tracing</h4>],
#  [],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">Successful Negotiation: Essential Strategies and Skills</h4>],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">English for Career Development</h4>],
#  [],
#  [<h4 class="headline-3-text item-name font-weight-bold">Financial Engineering and Risk Management Part I</h4>],
#  [],
# ...

# %%
import pandas as pd
import numpy as np
import requests
import re
from bs4 import BeautifulSoup

# %%
url='https://www.coursera.org/collections/popular-free-courses'
webpage=requests.get(url)

# %%
data=BeautifulSoup(webpage.content)

# %%
print(data.prettify)

# %%
course_name=[]
course_rating=[]
course_provider=[]
course_reviews=[]

for i in content.findAll('div', class_='horizontal-box'):
    course = i.findAll('h4', class_='headline-3-text item-name font-weight-bold')
    if course!=[]:
      course_names.append(course[0].text.split('\n')[0])

# %%
course_df = pd.DataFrame()
course_df['Name'] = course_names


course_df
# Out:
#                                                   Name
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 140                              Computer Architecture
# 141                   Writing in English at University
# 142                                          Chemistry
# 143         Resilience Skills in a Time of Uncertainty
# 144  Fighting COVID-19 with Epidemiology: A Johns H...
#
# [145 rows x 1 columns]
